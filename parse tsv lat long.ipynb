# %%
import csv

f = "workspace/sunrise_by_city/2012_metro_micro_lat_long.tsv"
with open(f) as tsv:
    for line in csv.reader(tsv, dialect="excel-tab"): #You can also use delimiter="\t" rather than giving a dialect.
        print line[1] + " " + line[7] + " " + line[8]
# Out:
# NAME INTPTLAT INTPTLONG
# Abbeville, LA Urban Cluster  29.967602  -92.098219
# Abbeville, SC Urban Cluster  34.179237  -82.379726
# Abbotsford, WI Urban Cluster  44.948612  -90.315875
# Aberdeen, MS Urban Cluster  33.824742  -88.554591
# Aberdeen, SD Urban Cluster  45.463186  -98.471033
# Aberdeen, WA Urban Cluster  46.976365 -123.796056
# Aberdeen--Bel Air South--Bel Air North, MD Urbanized Area  39.508976  -76.303431
# Abernathy, TX Urban Cluster  33.830523 -101.846278
# Abilene, KS Urban Cluster  38.921060  -97.220754
# Abilene, TX Urbanized Area  32.428784  -99.747194
# Abingdon, IL Urban Cluster  40.804175  -90.401522
# Ada, OH Urban Cluster  40.767274  -83.824641
# Ada, OK Urban Cluster  34.774803  -96.669103
# Adams, NY Urban Cluster  43.808664  -76.021178
# Adel, GA Urban Cluster  31.145731  -83.429099
# Adel, IA Urban Cluster  41.612208  -94.021014
# Adjuntas, PR Urban Cluster  18.166604  -66.729934
# Adrian, MI Urban Cluster  41.914086  -84.049778
# ...

# %%
cd C:\Users\mstubbs\workspace\data viz sandbox\sunrise by city\
# Out:
# C:\Users\mstubbs\workspace\data viz sandbox\sunrise by city

# %%
import json
json_data=open('time_after_sunrise.json')

data = json.load(json_data)

# %%
print data[0]['geography']
# Out:
# Pierre Part, LA Micro Area

# %%
for item in data:
    q1 = int(item['q1'])
    if q1 > 0:
        print item['geography'] + ' ' + item['q1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-b9007cee22e1> in <module>()
#       1 for item in data:
# ----> 2     q1 = int(item['q1'])
#       3     if q1 > 0:
#       4         print item['geography'] + ' ' + item['q1']
#       5
#
# KeyError: 'q1'
# Adjuntas, PR Micro Area 11
# Alexander City, AL Micro Area 2
# Glasgow, KY Micro Area 9
# Santa Isabel, PR Micro Area 8
# McMinnville, TN Micro Area 6
# Jayuya, PR Micro Area 2
# Albertville, AL Micro Area 8
# Yauco, PR Metro Area 9
# Eufaula, AL-GA Micro Area 15
# Lewisburg, TN Micro Area 7
# Guayama, PR Metro Area 12
# San Juan-Caguas-Guaynabo, PR Metro Area 15
# Utuado, PR Micro Area 12
# San Germ�n-Cabo Rojo, PR Metro Area 16
# Crossville, TN Micro Area 33
# Tupelo, MS Micro Area 8
# Berlin, NH-VT Micro Area 13
# Central City, KY Micro Area 3
# Ponce, PR Metro Area 10
# Decatur, AL Metro Area 6
# ...

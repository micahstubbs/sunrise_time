# %%
import csv

filepath = 'workspace/sunrise_by_city/towns_source.csv'
reader = csv.reader(open(filepath), delimiter=',', quotechar='"')

towns_source = {
    rows[0] : {
              'lat':rows[1],
              'long':rows[2]
              } for rows in reader }

# %%
print towns_source
# Out:
# {'Lima, OH': {'lat': '40.739655', 'long': '-84.119864'}, 'Wabash, IN': {'lat': '40.801738', 'long': '-85.827412'}, 'Centralia, IL': {'lat': '38.517291', 'long': '-89.132952'}, 'Spearfish, SD': {'lat': '44.494386', 'long': '-103.854997'}, 'Rapid City, SD': {'lat': '44.0837', 'long': '-103.244558'}, 'Kankakee, IL': {'lat': '41.150152', 'long': '-87.862319'}, 'Seymour, IN': {'lat': '38.955122', 'long': '-85.883768'}, 'Fort Wayne, IN': {'lat': '41.100389', 'long': '-85.138898'}, 'Magnolia, AR': {'lat': '33.274019', 'long': '-93.23365'}, 'Bend, OR': {'lat': '44.04927', 'long': '-121.312835'}, 'Scottsbluff, NE': {'lat': '41.854912', 'long': '-103.667671'}, 'Tulsa, OK': {'lat': '36.105449', 'long': '-95.901334'}, 'Kodiak, AK': {'lat': '57.803822', 'long': '-152.372007'}, 'Somerset, KY': {'lat': '37.064952', 'long': '-84.626263'}, 'Tallulah, LA': {'lat': '32.406005', 'long': '-91.187177'}, 'Glasgow, KY': {'lat': '36.997889', 'long': '-85.925425'}, 'Morgan City, LA': {'lat': '29.69095', 'long
# ...

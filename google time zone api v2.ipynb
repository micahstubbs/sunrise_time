# %%
import csv

filepath = 'workspace/sunrise_by_city/towns_source.csv'
reader = csv.reader(open(filepath), delimiter=',', quotechar='"')

towns = {
    rows[0] : {
              'lat':rows[1],
              'long':rows[2]
              } for rows in reader }

# %%
for town in towns:

    base_url = 'https://maps.googleapis.com/maps/api/timezone/json?location='
    #
    lat = towns[town]['lat']
    long = towns[town]['long']
    timestamp_value = '1331766000'
    sensor_flag = 'false'
    key = 'AIzaSyApU0WhX-Y1c92q4WhONPceDTVQtUrMQvM'
    #
    url = base_url + lat + ',' + long + '&timestamp=' + timestamp_value + '&sensor=' + sensor_flag + '&key=' + key

    import requests
    r = requests.get(url)
    r.json()

    import json
    data=r.json()
    towns[town].update(data)
    
print data
print 
print towns
# Out:
# {u'status': u'OK', u'dstOffset': 3600, u'rawOffset': -18000, u'timeZoneName': u'Eastern Daylight Time', u'timeZoneId': u'America/New_York'}
#
# ...

# %%
for key, value in towns.items():
    hoursOffset = value['rawOffset']/3600
    print str(key) + ' ' + str(hoursOffset)
# Out:
# Lima, OH -5
# Wabash, IN -5
# Centralia, IL -6
# Spearfish, SD -7
# Rapid City, SD -7
# Kankakee, IL -6
# Seymour, IN -5
# Fort Wayne, IN -5
# Magnolia, AR -6
# Bend, OR -8
# Scottsbluff, NE -7
# Tulsa, OK -6
# Kodiak, AK -9
# Somerset, KY -5
# Tallulah, LA -6
# Glasgow, KY -6
# Morgan City, LA -6
# Meadville, PA -5
# Portsmouth, OH -5
# Sanford, NC -5
# Poplar Bluff, MO -6
# Fallon, NV -8
# Jesup, GA -5
# Guymon, OK -6
# Grand Island, NE -6
# Anniston, AL -6
# Oshkosh, WI -6
# Thomasville, GA -5
# Scottsburg, IN -5
# Pittsfield, MA -5
# Great Falls, MT -7
# Statesboro, GA -5
# Clinton, IA -6
# Clearlake, CA -8
# Vermillion, SD -6
# McMinnville, TN -6
# Yuma, AZ -7
# Murray, KY -6
# Hilton Head Island, SC -5
# Reading, PA -5
# Parsons, KS -6
# Hastings, NE -6
# Easton, MD -5
# Moses Lake, WA -8
# South Bend, IN -5
# Pierre Part, LA -6
# Jamestown, NY -5
# Elmira, NY -5
# Spokane, WA -8
# New Philadelphia, OH -5
# Cumberland, MD -5
# Bellingham, WA -8
# Dodge City, KS -6
# ...

# %%
import json
with open('towns.txt', 'w') as outfile:
  json.dump(towns, outfile)
